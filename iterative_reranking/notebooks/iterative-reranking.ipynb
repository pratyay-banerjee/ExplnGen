# %%
import operator
import spacy
nlp = spacy.load("en_core_web_lg")
import nltk
from nltk.corpus import stopwords
stpwords =  set(stopwords.words('english'))
from nltk.stem.porter import PorterStemmer
stemmer = PorterStemmer()

# %%
# %install_ext https://raw.github.com/cpcloud/ipython-autotime/master/autotime.py
# %load_ext autotime
# Out:
# UsageError: Line magic function `%install_ext` not found.

# %%
import pandas as pd

# %%
docmap={}

# %%
dev_score = pd.read_csv("mod_data/dev-unscored.tsv-score.tsv",delimiter="\t",names=["id","score"])

# %%
test_score = pd.read_csv("mod_data/test.tsv-score.tsv",delimiter="\t",names=["id","score"])

# %%
dev = pd.read_csv("mod_data/dev-unscored.tsv",delimiter="\t",names=["id","hyp","fact","label"])

# %%
testdf = pd.read_csv("mod_data/test.tsv",delimiter="\t",names=["id","hyp","fact","label"])

# %%
dev_merged = pd.merge(dev_score, dev, on='id')

# %%
test_merged = pd.merge(test_score,testdf, on="id")

# %%
dev_merged.head()
# Out:
#                                     id     score  \
# 0  VASoL_2008_3_26:14a5-1229-3653-681c  0.000263
# 1  VASoL_2008_3_26:12d9-60df-23de-f00f  0.000223
# 2  VASoL_2008_3_26:e1fb-b791-3945-02db  0.000309
# 3  VASoL_2008_3_26:244b-03a0-929e-0095  0.000584
# 4  VASoL_2008_3_26:22ce-038b-ff4f-c5ba  0.000319
#
#                                                  hyp  \
# 0  Which of these is MOST flexible?  Drinking straw
# 1  Which of these is MOST flexible?  Drinking straw
# 2  Which of these is MOST flexible?  Drinking straw
# 3  Which of these is MOST flexible?  Drinking straw
# 4  Which of these is MOST flexible?  Drinking straw
#
#                                                 fact  label
# 0  a landslide is when water; gravity rapidly mov...      0
# 1  decomposition is when a decomposer recycles; r...      0
# 2  deposition means to move an object from one lo...      0
# 3  eating;digestion is when an organism takes in ...      0
# ...

# %%
test_merged.head()
# Out:
#                                       id     score  \
# 0  Mercury_SC_402645:14a5-1229-3653-681c  0.000426
# 1  Mercury_SC_402645:12d9-60df-23de-f00f  0.000238
# 2  Mercury_SC_402645:e1fb-b791-3945-02db  0.000218
# 3  Mercury_SC_402645:244b-03a0-929e-0095  0.000514
# 4  Mercury_SC_402645:22ce-038b-ff4f-c5ba  0.000249
#
#                                                  hyp  \
# 0  Which best describes what keeps the Moon orbit...
# 1  Which best describes what keeps the Moon orbit...
# 2  Which best describes what keeps the Moon orbit...
# 3  Which best describes what keeps the Moon orbit...
# 4  Which best describes what keeps the Moon orbit...
#
#                                                 fact  label
# 0  a landslide is when water; gravity rapidly mov...      0
# 1  decomposition is when a decomposer recycles; r...      0
# 2  deposition means to move an object from one lo...      0
# 3  eating;digestion is when an organism takes in ...      0
# ...

# %%
global_c = 0

# %%
explanations = pd.read_csv("../explanations.csv")
explanation_map = {}
for index,row in tqdm(explanations.iterrows()):
    explanation_map[row['uid']] = row['text']
# Out:
# 0it [00:00, ?it/s]
#
#
#
#
#
#
#
#
# 899it [00:00, 8988.96it/s]
#
#
#
#
#
#
#
#
# 1768it [00:00, 8896.41it/s]
#
#
#
#
#
#
#
#
# 2681it [00:00, 8965.05it/s]
#
#
#
#
#
#
#
#
# 3567it [00:00, 8931.39it/s]
#
#
#
#
#
#
#
#
# 4458it [00:00, 8922.57it/s]
#
#
#
#
#
#
#
#
# 4950it [00:00, 8882.25it/s]

# %%
exp_exp_simscore = {}
for uid1,exp1 in tqdm(explanation_map.items()):
    exp1doc = get_doc(exp1)
    exp_exp_simscore[exp1]={}
    for uid2,exp2 in explanation_map.items():
        exp2doc = get_doc(exp2)
        exp_exp_simscore[exp1][exp2]=exp1doc.similarity(exp2doc)
# Out:
#   0%|          | 0/4947 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#   0%|          | 3/4947 [00:00<03:07, 26.36it/s]
#
#
#
#
#
#
#
#
#   0%|          | 5/4947 [00:00<03:26, 23.96it/s]
#
#
#
#
#
#
#
#
#   0%|          | 7/4947 [00:00<04:57, 16.59it/s]
#
#
#
#
#
#
#
#
#   0%|          | 10/4947 [00:00<04:26, 18.55it/s]
#
#
#
#
#
#
#
#
#   0%|          | 13/4947 [00:00<04:01, 20.46it/s]
#
#
#
#
#
#
#
#
#   0%|          | 16/4947 [00:00<03:48, 21.56it/s]
#
#
#
#
#
#
#
#
#   0%|          | 19/4947 [00:00<03:33, 23.03it/s]
#
#
#
#
#
#
#
#
#   0%|          | 22/4947 [00:01<04:14, 19.31it/s]
#
#
#
#
#
#
#
#
#   1%|          | 25/4947 [00:01<04:02, 20.32it/s]
#
#
#
#
#
#
#
#
#   1%|          | 28/4947 [00:01<03:50, 21.39it/s]
#
#
#
#
#
#
#
#
#   1%|          | 31/4947 [00:01<03:39, 22.40it/s]
#
#
#
#
#
#
#
#
#   1%|          | 34/4947 [00:01<03:29, 23.41it/s]
#
#
#
#
#
#
#
#
#   1%|          | 37/4947 [00:01<03:46, 21.67it/s]
#
#
#
#
#
#
#
#
#   1%|          | 40/4947 [00:01<04:04, 20.07it/s]
#
#
#
#
# ...

# %%
hyp_exp_simscore = {}
for uid1,hyp1 in tqdm(hypmap.items()):
    hyp1doc = get_doc(hyp1)
    hyp_exp_simscore[hyp1]={}
    for uid2,exp2 in explanation_map.items():
        exp2doc = get_doc(exp2)
        hyp_exp_simscore[hyp1][exp2]=hyp1doc.similarity(exp2doc)
# Out:
#   0%|          | 0/264 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#   1%|          | 3/264 [00:00<00:10, 24.90it/s]
#
#
#
#
#
#
#
#
#   2%|▏         | 6/264 [00:00<00:10, 24.29it/s]
#
#
#
#
#
#
#
#
#   3%|▎         | 9/264 [00:00<00:10, 24.54it/s]
#
#
#
#
#
#
#
#
#   5%|▍         | 12/264 [00:00<00:10, 24.11it/s]
#
#
#
#
#
#
#
#
#   6%|▌         | 15/264 [00:00<00:10, 24.36it/s]
#
#
#
#
#
#
#
#
#   7%|▋         | 18/264 [00:00<00:10, 24.26it/s]
#
#
#
#
#
#
#
#
#   8%|▊         | 21/264 [00:00<00:09, 24.95it/s]
#
#
#
#
#
#
#
#
#   9%|▉         | 24/264 [00:00<00:09, 24.84it/s]
#
#
#
#
#
#
#
#
#  10%|█         | 27/264 [00:01<00:09, 25.02it/s]
#
#
#
#
#
#
#
#
#  11%|█▏        | 30/264 [00:01<00:09, 24.88it/s]
#
#
#
#
#
#
#
#
#  12%|█▎        | 33/264 [00:01<00:09, 24.70it/s]
#
#
#
#
#
#
#
#
#  14%|█▎        | 36/264 [00:01<00:09, 25.18it/s]
#
#
#
#
#
#
#
#
#  15%|█▍        | 39/264 [00:01<00:09, 24.84it/s]
#
#
#
#
#
#
#
#
#  16%|█▌        | 42/264 [00:01<00:08, 24.99it/s]
#
#
#
#
#
#
#
#
# ...

# %%
for uid1,hyp1 in tqdm(hypmap1.items()):
    hyp1doc = get_doc(hyp1)
    hyp_exp_simscore[hyp1]={}
    for uid2,exp2 in explanation_map.items():
        exp2doc = get_doc(exp2)
        hyp_exp_simscore[hyp1][exp2]=hyp1doc.similarity(exp2doc)

# %%
print(exp_exp_simscore['the moon orbiting the Earth approximately occurs 13 times per year']['approximately means about'])
print(exp_exp_simscore['approximately means about']['the moon orbiting the Earth approximately occurs 13 times per year'])
# Out:
# 0.7527900762401644
# 0.7527900762401644

# %%
import pickle
with open('docmap.pickled', 'wb+') as handle:
    pickle.dump(docmap, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
from tqdm import tqdm,tqdm_notebook
import string

def strip_punct(s):
    exclude = set(string.punctuation)
    s = ''.join(ch for ch in s if ch not in exclude)
    return s

def get_doc(docs):
    if docs in docmap:
        return docmap[docs]
    docmap[docs] = nlp(docs)
    return docmap[docs]

def process_string(inp):
    inp = strip_punct(inp)
    inp = inp.lower()
    uniq_words = set(inp.split(" "))
    return set(map(stemmer.stem,uniq_words))

def is_same_as_ans(choice,f2):
    f2 = set(map(stemmer.stem,strip_punct(f2).lower().split(" "))) -set([''])
    choice = set(map(stemmer.stem,strip_punct(choice).lower().split(" "))) -set([''])
    return len(f2-choice) == 0 and len(choice-f2) == 0
    
def allow_add(eligible_s,all_entries):
    global global_c
    verbose=True
    ret = True
    eligible = process_string(eligible_s) - set([''])
    
    if len(eligible) <2:
        if verbose:
            print("Less Than 2!!",eligible,eligible_s)
        ret =  False
    for tup in all_entries:
#         print(tup)
        already_present = process_string(tup[1]) - set([''])
        if len(eligible - already_present) < 2:
            not_present = eligible - already_present
            if len(not_present) == 0:
                return False
            sim = 0
#             for word1 in already_present:
#                 temp = 0
#                 for word2 in not_present:
#                     temp = max(sim,get_doc(word1).similarity(get_doc(word2)))
#                 sim += temp
            
#             if sim/len(not_present) > 0.5 :
#                 if verbose: print("Failed Allowed Add:",eligible,already_present,tup[1],eligible_s)
#                 ret = False
#                 break
    
    if verbose:
        global_c+=1
        if global_c < 5:
            print(eligible,eligible_s,ret)
            
    return ret
    
    
def rerank(hyp,tups):    
    result = {}
    total_len = len(tups)
    src = tups
    result=[]  # Put the first in result
    result.append(src[0])
    curfact = src[0][1]
    cur = get_doc(src[0][1])
    cur_tup = src[0]
    src.remove(src[0])
    information_map_n = {}
    information_map_d = {}
#     hypdoc = get_doc(hyp)
    prev = None
    ixx =0
    done = {}
    done[curfact]=True
    
    while True:
        if len(result) == total_len:
            break
        ixx+=1
#         print(ixx)
#         if len(result)>10:
#             break
        temp = []
        for tup in src:
#             doc = get_doc(tup[1])
            if done.get(tup[1],False):
                continue
            numerinfo = information_map_n.get(tup[1],0)
            denominfo = information_map_d.get(tup[1],0)
#             for selfact in result:
#                 fact = selfact[1]
#                 fact_score = selfact[2]
#                 similarity_with_tup = exp_exp_simscore[fact][tup[1]]
#                 numerinfo += similarity_with_tup*fact_score
#                 denominfo += fact_score
            similarity_with_tup = exp_exp_simscore[curfact][tup[1]]
            fact_score = cur_tup[2]
            numerinfo += similarity_with_tup*fact_score
            denominfo += fact_score
            information_map_n[tup[1]]=numerinfo
            information_map_d[tup[1]]=denominfo
            information = numerinfo/denominfo
            similarity = hyp_exp_simscore[hyp][tup[1]]
            temp.append([tup[0],tup[1],tup[2],tup[2]*information*similarity])
        if len(temp) == 0:
            break
        sorted_x = sorted(temp, key=operator.itemgetter(-1),reverse=True)
        tup = sorted_x[0]
        result.append(tup)
#         src.remove([tup[0],tup[1],tup[2]])
        done[tup[1]]=True
        prev = cur
        curfact = tup[1]
        cur_tup = tup
#         print(information_map)
    
    cur = get_doc(tup[1])
    print(cur,prev)
#     sorted_x = sorted(result, key=operator.itemgetter(-1),reverse=True)
    return list(result)
    
#     for ixx in range(0,len(src)-1):
#         print(ixx)
#         temp=[]
# #         for tup in src:
# #             doc = get_doc(tup[1])
# #             information = cur.similarity(doc)
# #             information_gains[tup[1]] = max(information,information_gains.get(tup[1],0))  # Information
#         for tup in src:
# #             temp.append([tup[0],tup[1],tup[2],tup[2]*(1-information_gains.get(tup[1],0))])  # Redundancy - uid/fact/redundancy_score
#             doc = get_doc(tup[1])
#             information = cur.similarity(doc)
#             similarity = hypdoc.similarity(doc)
#             temp.append([tup[0],tup[1],tup[2],tup[2]*information*similarity])
#         if len(temp) == 0:
#             break
#         sorted_x = sorted(temp, key=operator.itemgetter(-1),reverse=True)
        
#         tup = sorted_x[0]
#         result.append(tup)
#         src.remove([tup[0],tup[1],tup[2]])
#         prev = cur
#         cur = get_doc(tup[1])
        
#         for tup in sorted_x:
#             eligible_string = tup[1]
# #             print(tup)
#             src.remove([tup[0],tup[1],tup[2]]) 
#             if allow_add(eligible_string,result):
#                 result.append(tup)
#                 prev=cur
#                 cur = get_doc(tup[1])
#                 break
#         if len(result)>9:
#             break
    
    
    
def get_score_map(df):
    q_uid_map = {}
    q_hyp_map = {}
    for index,row in tqdm(df.iterrows()):
        idx = row["id"]
        qid = idx.split(":")[0]
        uid = idx.split(":")[1]
        if qid not in q_uid_map:
            q_uid_map[qid]=[]
            q_hyp_map[qid] = row['hyp']
        q_uid_map[qid].append([uid,row['fact'],float(row['score'])])
        
    return q_uid_map,q_hyp_map

def rerank_dataframe(scoremap,hypmap):
    ir_dataset_f2= {}
    ix=0
    for qidx,rows in tqdm(scoremap.items()):
        sorted_x = sorted(rows, key=operator.itemgetter(-1),reverse=True)
        rows = rerank(hypmap[qidx],list(sorted_x))
#         if ix<1 or len(rows)==0:
#             print(rows)
#         ix+=1
        ir_dataset_f2[qidx]=rows
    return ir_dataset_f2

# %%
def rerank_qid(tup):
    qidx = tup[0]
    rows = tup[1]
    sorted_x = sorted(rows, key=operator.itemgetter(-1),reverse=True)
    rows = rerank(hypmap[qidx],list(sorted_x))
    return qidx,rows

# %%
scoremap,hypmap =get_score_map(dev_merged)
# Out:
# 0it [00:00, ?it/s]
#
#
#
#
# 1it [00:00,  3.82it/s]
#
#
#
#
# 795it [00:00,  5.46it/s]
#
#
#
#
# 1615it [00:00,  7.80it/s]
#
#
#
#
# 2403it [00:00, 11.14it/s]
#
#
#
#
# 3193it [00:00, 15.90it/s]
#
#
#
#
# 4010it [00:00, 22.70it/s]
#
#
#
#
# 4844it [00:00, 32.39it/s]
#
#
#
#
# 5660it [00:00, 46.19it/s]
#
#
#
#
# 6407it [00:01, 65.80it/s]
#
#
#
#
# 7203it [00:01, 93.67it/s]
#
#
#
#
# 8005it [00:01, 133.15it/s]
#
#
#
#
# 8805it [00:01, 188.87it/s]
#
#
#
#
# 9632it [00:01, 267.19it/s]
#
#
#
#
# 10467it [00:01, 376.54it/s]
#
#
#
#
# 11277it [00:01, 527.40it/s]
#
#
#
#
# 12084it [00:01, 732.75it/s]
#
#
#
#
# 12889it [00:01, 1007.05it/s]
#
#
#
#
# 13692it [00:01, 1364.50it/s]
#
#
#
#
# 14505it [00:02, 1818.37it/s]
#
#
#
#
# 15309it [00:02, 2366.77it/s]
#
#
#
#
# 16112it [00:02, 3001.41it/s]
#
#
#
#
# 16915it [00:02, 3695.70it/s]
#
#
#
#
# 17718it [00:02, 4385.14it/s]
#
#
#
#
# 18513it [00:02, 5065.49it/s]
#
#
#
#
# 19327it [00:02, 5711.81it/s]
#
#
#
#
# 20259it [00:02, 6461.10it/s]
#
#
#
#
# ...

# %%
scoremap1,hypmap1 = get_score_map(test_merged)
# Out:
# 0it [00:00, ?it/s]
#
#
#
#
#
#
#
#
#
# 1it [00:01,  1.46s/it]
#
#
#
#
#
#
#
#
#
# 945it [00:01,  1.02s/it]
#
#
#
#
#
#
#
#
#
# 1894it [00:01,  1.40it/s]
#
#
#
#
#
#
#
#
#
# 2838it [00:01,  2.00it/s]
#
#
#
#
#
#
#
#
#
# 3791it [00:01,  2.86it/s]
#
#
#
#
#
#
#
#
#
# 4748it [00:01,  4.08it/s]
#
#
#
#
#
#
#
#
#
# 5605it [00:02,  5.82it/s]
#
#
#
#
#
#
#
#
#
# 6558it [00:02,  8.32it/s]
#
#
#
#
#
#
#
#
#
# 7513it [00:02, 11.88it/s]
#
#
#
#
#
#
#
#
#
# 8468it [00:02, 16.96it/s]
#
#
#
#
#
#
#
#
#
# 9422it [00:02, 24.21it/s]
#
#
#
#
#
#
#
#
#
# 10371it [00:02, 34.55it/s]
#
#
#
#
#
#
#
#
#
# 11317it [00:02, 49.28it/s]
#
#
#
#
#
#
#
#
#
# 12270it [00:02, 70.25it/s]
#
#
#
#
#
#
#
#
#
# 13225it [00:02, 100.04it/s]
#
#
#
#
#
#
#
#
#
# 14184it [00:02, 142.28it/s]
#
#
#
#
#
#
#
#
#
# 15142it [00:03, 201.97it/s]
#
#
#
#
#
#
#
#
#
# 16099it [00:03, 285.94it/s]
#
#
#
#
#
#
#
#
#
# 17055it [00:03, 403.31it/s]
#
#
#
#
#
#
#
#
#
# 18014it [00:03, 565.96it/s]
#
#
#
#
#
#
#
#
#
# 18969it [00:03, 788.04it/s]
# ...

# %%
ir_dataset_f2 = rerank_dataframe(scoremap,hypmap)
# Out:
#   0%|          | 0/264 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#   0%|          | 1/264 [00:52<3:49:59, 52.47s/it]
# if weather is stormy then there is a greater chance of rain flexibility is a property of a material
#   1%|          | 2/264 [01:43<3:47:49, 52.17s/it]
# an adaptation is an adaptive feature planets have cleared their orbits
#   1%|          | 3/264 [02:35<3:46:24, 52.05s/it]
# to belong to a group means to be classified in that group sunlight produces heat
#   2%|▏         | 4/264 [03:31<3:50:15, 53.14s/it]
# a prism is used for refracting light come down is similar to falling
#   2%|▏         | 5/264 [04:29<3:55:42, 54.60s/it]
# if weather is stormy then there is a greater chance of rain requiring is similar to needing help
#   2%|▏         | 6/264 [05:28<4:00:11, 55.86s/it]
# when a body of water receives more water than it can hold , a flood occurs material means substance
#   3%|▎         | 7/264 [06:24<4:00:25, 56.13s/it]
# ...

# %%
dev_merged[dev_merged['id'] == 'VASoL_2008_3_26:bfdf-b468-ee22-1b60']['hyp']
# Out:
# 46    Which of these is MOST flexible?  Drinking straw
# Name: hyp, dtype: object

# %%
# Last : 1 Can select a bad one and penalize right ones 
# All  : If you give weight to all selected then it heavily bias towards wrong ones
# Weighted : relevance * sim/Sum(relevance)

# %%
# %%time
rerank(hypmap['Mercury_SC_415491'],sorted(scoremap['Mercury_SC_415491'], key=operator.itemgetter(-1),reverse=True))
# Out:
# an adaptation is an adaptive feature planets have cleared their orbits
# CPU times: user 49.4 s, sys: 1.04 s, total: 50.5 s
# Wall time: 53.5 s
# [['123d-9df4-bf21-0c14',
#   'planets have cleared their orbits',
#   0.997649517139974],
#  ['a6a9-3e1b-7e02-ce06',
#   'the moon orbits the Earth',
#   0.997556113374818,
#   0.669061053991929],
#  ['e70b-e515-02a3-8958',
#   'the moon revolving around; orbiting the Earth causes the phases of the moon',
#   0.9643214491222696,
#   0.7154224836016445],
#  ['1a29-2268-eeb7-edba',
#   'the moon orbiting the Earth approximately occurs 13 times per year',
#   0.9975465717403024,
#   0.7203699227305083],
#  ['cb34-8d7a-925d-de4d',
#   "the Moon is Earth's moon",
#   0.9956261768572005,
#   0.70512167009907],
#  ['e682-f47d-cc9c-a67c',
#   'a complete revolution of the Earth around the sun takes 1; one year; solar year; Earth year',
#   0.985949907393728,
#   0.7077988704209285],
#  ['1a6d-a427-8ac0-28bf',
#   'Earth is a kind of planet',
# ...

# %%
# %%time
rerank(hypmap['VASoL_2008_3_26'],sorted(scoremap['VASoL_2008_3_26'], key=operator.itemgetter(-1),reverse=True))
# Out:
# if weather is stormy then there is a greater chance of rain flexibility is a property of a material
# CPU times: user 50.7 s, sys: 1.05 s, total: 51.7 s
# Wall time: 54 s
# [['5109-65f3-6c0b-cecf',
#   'flexibility is a property of a material',
#   0.9974983032597357],
#  ['ac40-d9c4-86a2-f4bb',
#   'flexibility means the shape of a material; of an object can be easily changed',
#   0.995609133363186,
#   0.7794950288146569],
#  ['9349-71b6-e9b8-fd21',
#   'a drinking straw is a kind of object',
#   0.9943251245541888,
#   0.7449476364384007],
#  ['4bc1-99e4-3bcc-aac0',
#   'a drinking straw is flexible',
#   0.9969005844844906,
#   0.7105058709715876],
#  ['787c-b7eb-9067-f7f1',
#   'made up of means contains; made of',
#   0.9825407708074829,
#   0.6635872909609514],
#  ['1e4c-46e8-996c-f2f7',
#   'if an object is made of a material then that object has the properties of that material',
#   0.9038897076517898,
#   0.6669301392459536],
#  ['7c96-f704-e51e-1678',
# ...

# %%
ir_dataset_f2['VASoL_2008_3_26']
# Out:
# [['5109-65f3-6c0b-cecf',
#   'flexibility is a property of a material',
#   0.9974983032597357],
#  ['ac40-d9c4-86a2-f4bb',
#   'flexibility means the shape of a material; of an object can be easily changed',
#   0.995609133363186,
#   0.7794950288146569],
#  ['9349-71b6-e9b8-fd21',
#   'a drinking straw is a kind of object',
#   0.9943251245541888,
#   0.7449476364384007],
#  ['4bc1-99e4-3bcc-aac0',
#   'a drinking straw is flexible',
#   0.9969005844844906,
#   0.7105058709715876],
#  ['787c-b7eb-9067-f7f1',
#   'made up of means contains; made of',
#   0.9825407708074829,
#   0.6635872909609514],
#  ['1e4c-46e8-996c-f2f7',
#   'if an object is made of a material then that object has the properties of that material',
#   0.9038897076517898,
#   0.6669301392459536],
#  ['7c96-f704-e51e-1678',
#   'form means kind',
#   0.9973217821465036,
#   0.629295864484331],
#  ['3e18-eada-4a5f-aeef',
#   'composed of means made of',
#   0.9548162433273092,
#   0.6162510779390841],
# ...

# %%
def write_rerank_file(ir_map,fname):
    with open(fname+"-reranked.tsv","w+") as ofd:
        for uid,exps in tqdm(ir_map.items()):
            for tup in exps:
                ofd.write("%s\t%s\n"%(uid,tup[0]))

# %%
write_rerank_file(ir_dataset_f2,"dev-v3")
# Out:
#   0%|          | 0/264 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#   6%|▌         | 16/264 [00:00<00:01, 159.84it/s]
#
#
#
#
#
#
#
#
#
#  12%|█▎        | 33/264 [00:00<00:01, 161.07it/s]
#
#
#
#
#
#
#
#
#
#  19%|█▉        | 50/264 [00:00<00:01, 161.46it/s]
#
#
#
#
#
#
#
#
#
#  25%|██▌       | 67/264 [00:00<00:01, 162.70it/s]
#
#
#
#
#
#
#
#
#
#  32%|███▏      | 84/264 [00:00<00:01, 161.74it/s]
#
#
#
#
#
#
#
#
#
#  38%|███▊      | 101/264 [00:00<00:01, 162.74it/s]
#
#
#
#
#
#
#
#
#
#  44%|████▍     | 117/264 [00:00<00:00, 161.69it/s]
#
#
#
#
#
#
#
#
#
#  51%|█████     | 134/264 [00:00<00:00, 161.40it/s]
#
#
#
#
#
#
#
#
#
#  57%|█████▋    | 151/264 [00:00<00:00, 162.36it/s]
#
#
#
#
#
#
#
#
#
#  63%|██████▎   | 167/264 [00:01<00:00, 161.23it/s]
#
#
#
#
#
#
#
#
#
#  70%|██████▉   | 184/264 [00:01<00:00, 162.09it/s]
#
#
#
#
#
#
#
#
#
#  76%|███████▌  | 200/264 [00:01<00:00, 159.85it/s]
#
#
#
#
#
#
#
#
#
#  82%|████████▏ | 217/264 [00:01<00:00, 161.25it/s]
#
#
#
#
#
#
#
#
#
# ...

# %%
from joblib import Parallel, delayed
import multiprocessing

# %%
num_cores = multiprocessing.cpu_count()

# %%
num_cores
# Out:
# 20

# %%
top10 = list(scoremap.items())[0:10]

# %%
results = Parallel(n_jobs=10)(delayed(rerank_qid)(tup) for tup in top10)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-145-05956227d7e5> in <module>
# ----> 1 results = Parallel(n_jobs=10)(delayed(rerank_qid)(tup) for tup in top10)
#
# ~/.conda/envs/pytbuild/lib/python3.6/site-packages/joblib/parallel.py in __call__(self, iterable)
#     932
#     933             with self._backend.retrieval_context():
# --> 934                 self.retrieve()
#     935             # Make sure that we get a last message telling us we are done
#     936             elapsed_time = time.time() - self._start_time
#
# ~/.conda/envs/pytbuild/lib/python3.6/site-packages/joblib/parallel.py in retrieve(self)
#     831             try:
#     832                 if getattr(self._backend, 'supports_timeout', False):
# --> 833                     self._output.extend(job.get(timeout=self.timeout))
#     834                 else:
# ...
